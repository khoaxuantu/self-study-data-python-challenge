# %%
# Nice work, but you are hardcoding the class names too much, which makes your code not very clean.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from datetime import datetime

(
    names,
    market_caps,
    prices,
    volumes,
    timestamps,
    one_hours,
    twentyfour_hours,
    seven_days,
) = ([], [], [], [], [], [], [], [])
url = "https://coinmarketcap.com/historical/20240804/"
webpage = requests.get(url)
soup = BeautifulSoup(webpage.text, "html.parser")
rows = soup.find_all("tr", attrs={"class": "cmc-table-row"})

count = 0
number = 20
for row in rows:
    if count == number:
        break
    count += 1

    name_col = row.find(
        "td",
        attrs={
            "class": "cmc-table__cell cmc-table__cell--sticky cmc-table__cell--sortable cmc-table__cell--left cmc-table__cell--sort-by__name"
        },
    )
    cryptoname = name_col.find(
        "a", attrs={"class": "cmc-table__column-name--name cmc-link"}
    ).text.strip()
    marketcap = row.find(
        "td",
        attrs={
            "class": "cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__market-cap"
        },
    ).text.strip()
    crytoprice = row.find(
        "td",
        attrs={
            "class": "cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__price"
        },
    ).text.strip()
    volume = row.find(
        "td",
        attrs={
            "class": "cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__volume-24-h"
        },
    ).text.strip()
    one_hour = row.find(
        "td",
        attrs={
            "class": "cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__percent-change-1-h"
        },
    ).text.strip()
    twentyfour_hour = row.find(
        "td",
        attrs={
            "class": "cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__percent-change-24-h"
        },
    ).text.strip()
    seven_day = row.find(
        "td",
        attrs={
            "class": "cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__percent-change-7-d"
        },
    ).text.strip()
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    names.append(cryptoname)
    market_caps.append(marketcap)
    prices.append(crytoprice)
    volumes.append(volume)
    one_hours.append(one_hour)
    twentyfour_hours.append(twentyfour_hour)
    seven_days.append(seven_day)
    timestamps.append(timestamp)

df = pd.DataFrame(
    {
        "Name": names,
        "Market Cap": market_caps,
        "Price": prices,
        "Volume (24h)": volumes,
        "%1h": one_hours,
        "%24h": twentyfour_hours,
        "%7d": seven_days,
        "Timestamp": timestamps,
    }
)


print(df)
# Out:
#              Name             Market Cap        Price        Volume (24h)  \
# 0         Bitcoin  $1,146,976,665,063.02   $58,116.98  $31,758,917,219.16
# 1        Ethereum    $323,059,710,353.71    $2,686.40  $21,139,601,426.46
# 2     Tether USDt    $114,491,072,540.08      $0.9997  $58,452,540,745.78
# 3             BNB     $72,536,450,053.01      $497.04   $1,980,159,444.38
# 4          Solana     $64,261,166,209.76      $138.06   $4,333,596,295.62
# 5            USDC     $33,273,324,291.10      $0.9999   $6,455,293,009.26
# 6             XRP     $29,309,824,036.25      $0.5234   $1,209,933,394.24
# 7         Toncoin     $15,162,033,924.63      $6.0212     $361,349,746.55
# 8        Dogecoin     $15,082,960,842.07      $0.1037     $827,323,033.65
# 9         Cardano     $12,353,157,088.35      $0.3439     $317,908,629.25
# 10           TRON     $10,988,673,529.86      $0.1263     $405,632,493.82
# 11      Avalanche      $8,386,141,239.34       $21.23     $270,824,416.96
# 12      Shiba Inu      $7,855,215,132.81  $0.00001333     $268,114,247.91
# 13       Polkadot      $6,918,784,220.93      $4.6838     $183,256,631.72
# 14      Chainlink      $6,610,975,114.00       $10.87     $278,122,991.24
# 15   Bitcoin Cash      $6,551,712,415.15      $331.86     $338,173,941.85
# 16            Dai      $5,346,929,957.74      $0.9998     $170,218,254.59
# 17   UNUS SED LEO      $5,233,935,107.12      $5.6533       $8,852,028.02
# 18       Litecoin      $4,668,830,446.45       $62.40     $281,214,195.57
# 19  NEAR Protocol      $4,581,466,483.38      $4.1329     $237,776,667.59
#
#        %1h    %24h      %7d            Timestamp
# 0   -0.95%  -4.22%  -14.85%  2024-08-12 22:47:49
# 1   -1.24%  -7.47%  -17.88%  2024-08-12 22:47:49
# 2   -0.03%  <0.01%   -0.02%  2024-08-12 22:47:49
# 3   -1.35%  -6.13%  -14.91%  2024-08-12 22:47:49
# 4   -1.85%  -3.41%  -25.33%  2024-08-12 22:47:49
# 5   -0.02%  -0.01%   <0.01%  2024-08-12 22:47:49
# 6   -0.92%  -5.93%  -13.05%  2024-08-12 22:47:49
# 7   -0.65%   0.98%   -9.03%  2024-08-12 22:47:49
# 8   -1.43%  -4.10%  -20.25%  2024-08-12 22:47:49
# 9   -1.58%  -5.54%  -15.57%  2024-08-12 22:47:49
# 10  -0.14%   0.77%   -8.94%  2024-08-12 22:47:49
# 11  -1.71%  -6.42%  -22.53%  2024-08-12 22:47:49
# 12  -1.41%  -6.43%  -20.64%  2024-08-12 22:47:49
# 13  -1.63%  -7.13%  -18.14%  2024-08-12 22:47:49
# 14  -0.69%  -7.09%  -18.22%  2024-08-12 22:47:49
# 15  -2.43%  -8.93%  -20.36%  2024-08-12 22:47:49
# 16  <0.01%   0.00%   -0.01%  2024-08-12 22:47:49
# 17  <0.01%  -0.24%   -3.64%  2024-08-12 22:47:49
# 18  -1.29%  -3.42%  -12.28%  2024-08-12 22:47:49
# 19  -1.24%  -5.32%  -24.15%  2024-08-12 22:47:49
